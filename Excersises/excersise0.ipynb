# %%
import math
a = 3 
b = 4
c = math.sqrt(a**2 + b**2) 
print(c)
# Out:
# 5.0

# %%
import math 
a = 5
c = 7
b = math.sqrt(c**2 - a**2)
print(b)
# Out:
# 4.898979485566356

# %%
a = 365
b = 300
c = b/a
print(c)
# Out:
# 0.821917808219178

# %%
TP = 2
FP = 2
FN = 11
TN = 985
acc = (TP + TN)/(TP + FP + FN + TN)
print (acc)
# Out:
# 0.987

# %%
Ax = 0
Ay = 1
Bx = 4
By = 4
k = (4-1)/(4-0)
print(k)
m = By - (k*Bx)
print(m)
# Out:
# 0.75
# 1.0

# %%
import math
P1x = 3
P1y = 5
P2x = -2
P2y = 4
D = math.sqrt((P2x - P1x)**2 + (P2y - P1y)**2)
print(D)
# Out:
# 5.0990195135927845

# %%
import math
P1x = 2
P1y = 1
P1v = 4
P2x = 3
P2y = 1
P2v = 0
D = math.sqrt((P1x - P2x)**2 + (P1y - P2y)**2 + (P1v - P2v)**2)
print (D)
# Out:
# 4.123105625617661
